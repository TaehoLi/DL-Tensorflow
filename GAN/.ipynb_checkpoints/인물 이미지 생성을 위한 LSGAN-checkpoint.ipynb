# %%
# 필요한 라이브러리 불러들임 
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image as Im
import glob   
import os
# %matplotlib inline

# 그래프 리셋
tf.reset_default_graph() 
# 재현성위한 시드 설정
tf.set_random_seed(1)

#--------------------------------------------------
# data 불러오기
#--------------------------------------------------
files=glob.glob('./face20/*.png')
img=[]        
for file in files:
    temp=Im.open(file)
    temp=np.array(temp)
    temp=temp[:,:,0:3]/255. # RGBA에서 투명도를 나타내는  a(alpha) 를 삭제하여 RGB로
    img.append(temp)        

# 리스트를 array로
x=np.asarray(img)
n_cell=np.prod(x.shape[1:4]) # 45*40*3=5400
# 이미지를 벡터로 =[20,5400]
X_vec=np.reshape(x,[len(img),n_cell])

# 관측치 수
sample_size=X_vec.shape[0] #=20
# 입력 변수 수
input_dim = X_vec.shape[1] #=5400


#-------------------------------------------
# 매개변수 설정
#-------------------------------------------
# 입력 잡음신호의 차원: 100
# 생성자의 두 은닉층 크기: 128
# 판별자의 두 은닉층 크기: 128
# 미니배치 크기: 20
# 반복 수: 500
# 학습률 : 0.001
learning_rate = 0.001
batch_size = 20
z_size = 100
nepochs = 500  
g_hidden_size = 128 # 생성자 은닉층 크기
d_hidden_size = 128 # 판별자  은닉층 크기

# 드롭아웃에서 보존할 노드의 비율
keep_prob = tf.placeholder(tf.float32,name='keep_prob')

# 진짜데이터 placeholder
X = tf.placeholder(tf.float32, shape=[None, input_dim], name='X')
# 잡음 placeholder
Z = tf.placeholder(tf.float32, shape=[None, z_size], name='Z')

# 생성망의 가중치와 편의 정의(# 사비에르 초기치 사용)
G_W1 = tf.get_variable('G_W1',shape=[z_size,g_hidden_size],initializer=tf.contrib.layers.xavier_initializer())
G_b1 = tf.Variable(tf.zeros(shape=[g_hidden_size]), name='G_b1')
G_W2 = tf.get_variable('G_W2',shape=[g_hidden_size,input_dim],initializer=tf.contrib.layers.xavier_initializer())
G_b2 = tf.Variable(tf.zeros(shape=[input_dim]), name='G_b2')
theta_G = [G_W1, G_W2, G_b1, G_b2]

# 판별망의 가중치와 편의 정의(# 사비에르 초기치 사용)
D_W1 = tf.get_variable('D_W1',shape=[input_dim,d_hidden_size],initializer=tf.contrib.layers.xavier_initializer())
D_b1 = tf.Variable(tf.random_normal([d_hidden_size]), name='D_b1')
D_W2 = tf.get_variable('D_W2',shape=[d_hidden_size,1],initializer=tf.contrib.layers.xavier_initializer())
D_b2 = tf.Variable(tf.random_normal([1]), name='D_b2')
theta_D = [D_W1, D_W2, D_b1, D_b2]

#------------------------------------------------
# 생성자 정의: 입력된 진짜 데이터와 유사한 가짜 데이터 생성
#------------------------------------------------
def generator(z):
        h1 = tf.matmul(z, G_W1) + G_b1        
        h1 = tf.maximum(0., h1)  #ReLU
        h2 = tf.matmul(h1, G_W2) + G_b2
        out = tf.nn.tanh(h2) 
        return out

#------------------------------------------------
# 판별자 정의: 입력된 진짜 데이터와 가짜 데이터를 정확하게 분류
#------------------------------------------------
def discriminator(x):
        h1=tf.matmul(x, D_W1) + D_b1        
        h1 = tf.maximum(0., h1)  #ReLU  
        h1=tf.nn.dropout(h1, keep_prob)
        h2 = tf.matmul(h1, D_W2) + D_b2
        h2=tf.nn.dropout(h2, keep_prob)
        prob = tf.nn.sigmoid(h2)
        return prob, h2

G = generator(Z) # 가짜데이터
# 진짜 데이터의 판별망 결과 
D_real, D_logit_real = discriminator(X) 
# 가짜 데이터의 판별망 결과 
D_fake, D_logit_fake = discriminator(G)

# 비용함수 
# 판별자는 진짜데이터는 1, 가짜데이터는 0이 되게 
D_loss = 0.5 * (tf.reduce_mean((D_real - 1)**2) + 0.5*tf.reduce_mean(D_fake**2))
# 생성자는 가짜데이터의 판별망 결과가 1이 되게 만들어야 한다 
G_loss = 0.5 * tf.reduce_mean((D_fake - 1)**2)

# 판별망을 훈련할 때는  theta_D 만 업데이트 된다.
D_solver = tf.train.AdamOptimizer(learning_rate).minimize(D_loss, var_list=theta_D)
# 생성망 훈련할 때는  theta_G 만 업데이트 된다.
G_solver = tf.train.AdamOptimizer(learning_rate).minimize(G_loss, var_list=theta_G)

#------------------------------------------------
# 텐서플로 그래프 생성 및 학습 
#------------------------------------------------
sess=tf.Session(); 
sess.run(tf.global_variables_initializer())
losses = []

for epoch in range(nepochs):
    n_batch=int(sample_size/batch_size)
    
    for ii in range(n_batch):
        if ii!=n_batch:
              batch_images=X_vec[ii*batch_size:(ii+1)*batch_size]
        else:
              batch_images=X_vec[(ii+1)*batch_size:]           
        batch_images = batch_images*2 - 1   
        batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size)) 
        D_loss_curr,_ =sess.run([D_loss,D_solver], feed_dict={X: batch_images, Z: batch_z,keep_prob:0.8})
        G_loss_curr,_=sess.run([G_loss,G_solver], feed_dict={X: batch_images, Z: batch_z,keep_prob:0.8})               
        losss=D_loss_curr+G_loss_curr
        
    print('Epoch: {0}, Discriminator Loss: {1:7.4f}, Generator Loss: {2:7.4f}'  .format(epoch+1,D_loss_curr, G_loss_curr))
    losses.append((D_loss_curr, G_loss_curr))    
    # 100 에폭 마다 가짜데이터 그림    
    if (epoch+1)%100==0:
        tf.set_random_seed(0)
        sample_z = np.random.uniform(-1, 1, size=(20,z_size))
        gen_samples = sess.run(G,feed_dict={Z: sample_z})
        f,axes =plt.subplots(figsize=(7,7), nrows=5, ncols=4, sharey=True, sharex=True)
        f.suptitle(epoch+1)
        for ii in range(20):
            plt.subplot(5,4,ii+1)
            gs=gen_samples[ii].reshape(45,40,3); 
            gs=(gs-np.min(gs))/(np.max(gs)-np.min(gs))
            plt.imshow(gs)

# 판별자, 생성자의 비용함수 그림 
fig, ax = plt.subplots(figsize=(7,7))
losses = np.array(losses)
plt.plot(losses.T[0], 'r-',label='Discriminator')
plt.plot(losses.T[1], 'b-',label='Generator')

plt.title("Training Losses")
plt.legend()


#진짜 이미지 그림
f,axes =plt.subplots(figsize=(7,7), nrows=5, ncols=4, sharey=True, sharex=True)
for ii in range(20):
    plt.subplot(5,4,ii+1)
    gs=X_vec[ii].reshape(45,40,3);  gs=(gs-np.min(gs))/(np.max(gs)-np.min(gs))
    plt.imshow(gs)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-1-0dff42c2c126>:92: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Epoch: 1, Discriminator Loss:  0.2132, Generator Loss:  0.0643
# Epoch: 2, Discriminator Loss:  0.2285, Generator Loss:  0.0194
# Epoch: 3, Discriminator Loss:  0.2364, Generator Loss:  0.0126
# Epoch: 4, Discriminator Loss:  0.2385, Generator Loss:  0.0250
# Epoch: 5, Discriminator Loss:  0.2307, Generator Loss:  0.0188
# Epoch: 6, Discriminator Loss:  0.2371, Generator Loss:  0.0063
# Epoch: 7, Discriminator Loss:  0.2528, Generator Loss:  0.0125
# Epoch: 8, Discriminator Loss:  0.2186, Generator Loss:  0.0063
# Epoch: 9, Discriminator Loss:  0.2312, Generator Loss:  0.0250
# Epoch: 10, Discriminator Loss:  0.2062, Generator Loss:  0.0063
# Epoch: 11, Discriminator Loss:  0.2499, Generator Loss:  0.0250
# Epoch: 12, Discriminator Loss:  0.2562, Generator Loss:  0.0188
# Epoch: 13, Discriminator Loss:  0.2718, Generator Loss:  0.0250
# Epoch: 14, Discriminator Loss:  0.2375, Generator Loss:  0.0250
# Epoch: 15, Discriminator Loss:  0.2844, Generator Loss:  0.0125
# Epoch: 16, Discriminator Loss:  0.2156, Generator Loss:  0.0125
# Epoch: 17, Discriminator Loss:  0.2593, Generator Loss:  0.0375
# Epoch: 18, Discriminator Loss:  0.2250, Generator Loss:  0.0063
# Epoch: 19, Discriminator Loss:  0.2344, Generator Loss:  0.0188
# Epoch: 20, Discriminator Loss:  0.2406, Generator Loss:  0.0188
# Epoch: 21, Discriminator Loss:  0.2250, Generator Loss:  0.0000
# Epoch: 22, Discriminator Loss:  0.2249, Generator Loss:  0.0125
# Epoch: 23, Discriminator Loss:  0.2437, Generator Loss:  0.0188
# Epoch: 24, Discriminator Loss:  0.2250, Generator Loss:  0.0438
# Epoch: 25, Discriminator Loss:  0.2250, Generator Loss:  0.0313
# Epoch: 26, Discriminator Loss:  0.2375, Generator Loss:  0.0188
# Epoch: 27, Discriminator Loss:  0.2562, Generator Loss:  0.0250
# Epoch: 28, Discriminator Loss:  0.2125, Generator Loss:  0.0250
# Epoch: 29, Discriminator Loss:  0.2625, Generator Loss:  0.0312
# Epoch: 30, Discriminator Loss:  0.2749, Generator Loss:  0.0250
# Epoch: 31, Discriminator Loss:  0.2062, Generator Loss:  0.0125
# Epoch: 32, Discriminator Loss:  0.2156, Generator Loss:  0.0437
# Epoch: 33, Discriminator Loss:  0.2062, Generator Loss:  0.0375
# Epoch: 34, Discriminator Loss:  0.2812, Generator Loss:  0.0250
# Epoch: 35, Discriminator Loss:  0.2094, Generator Loss:  0.0063
# Epoch: 36, Discriminator Loss:  0.1937, Generator Loss:  0.0188
# Epoch: 37, Discriminator Loss:  0.2500, Generator Loss:  0.0250
# Epoch: 38, Discriminator Loss:  0.2031, Generator Loss:  0.0125
# Epoch: 39, Discriminator Loss:  0.2468, Generator Loss:  0.0188
# Epoch: 40, Discriminator Loss:  0.2344, Generator Loss:  0.0188
# Epoch: 41, Discriminator Loss:  0.2375, Generator Loss:  0.0188
# Epoch: 42, Discriminator Loss:  0.2062, Generator Loss:  0.0313
# Epoch: 43, Discriminator Loss:  0.2469, Generator Loss:  0.0375
# Epoch: 44, Discriminator Loss:  0.2125, Generator Loss:  0.0188
# Epoch: 45, Discriminator Loss:  0.2594, Generator Loss:  0.0188
# Epoch: 46, Discriminator Loss:  0.2312, Generator Loss:  0.0125
# Epoch: 47, Discriminator Loss:  0.2437, Generator Loss:  0.0125
# Epoch: 48, Discriminator Loss:  0.2031, Generator Loss:  0.0250
# Epoch: 49, Discriminator Loss:  0.2437, Generator Loss:  0.0250
# Epoch: 50, Discriminator Loss:  0.2562, Generator Loss:  0.0188
# Epoch: 51, Discriminator Loss:  0.1687, Generator Loss:  0.0375
# Epoch: 52, Discriminator Loss:  0.2312, Generator Loss:  0.0438
# Epoch: 53, Discriminator Loss:  0.2437, Generator Loss:  0.0250
# Epoch: 54, Discriminator Loss:  0.2531, Generator Loss:  0.0375
# Epoch: 55, Discriminator Loss:  0.2500, Generator Loss:  0.0313
# Epoch: 56, Discriminator Loss:  0.2312, Generator Loss:  0.0188
# Epoch: 57, Discriminator Loss:  0.2437, Generator Loss:  0.0188
# Epoch: 58, Discriminator Loss:  0.2500, Generator Loss:  0.0250
# Epoch: 59, Discriminator Loss:  0.2125, Generator Loss:  0.0125
# Epoch: 60, Discriminator Loss:  0.2312, Generator Loss:  0.0125
# Epoch: 61, Discriminator Loss:  0.2186, Generator Loss:  0.0000
# Epoch: 62, Discriminator Loss:  0.2184, Generator Loss:  0.0250
# Epoch: 63, Discriminator Loss:  0.2466, Generator Loss:  0.0250
# Epoch: 64, Discriminator Loss:  0.2217, Generator Loss:  0.0250
# Epoch: 65, Discriminator Loss:  0.2311, Generator Loss:  0.0375
# Epoch: 66, Discriminator Loss:  0.1904, Generator Loss:  0.0188
# Epoch: 67, Discriminator Loss:  0.2279, Generator Loss:  0.0250
# Epoch: 68, Discriminator Loss:  0.2373, Generator Loss:  0.0125
# Epoch: 69, Discriminator Loss:  0.2214, Generator Loss:  0.0313
# Epoch: 70, Discriminator Loss:  0.2047, Generator Loss:  0.0188
# Epoch: 71, Discriminator Loss:  0.1990, Generator Loss:  0.0198
# Epoch: 72, Discriminator Loss:  0.2306, Generator Loss:  0.0251
# Epoch: 73, Discriminator Loss:  0.2305, Generator Loss:  0.0270
# Epoch: 74, Discriminator Loss:  0.2099, Generator Loss:  0.0321
# Epoch: 75, Discriminator Loss:  0.2510, Generator Loss:  0.0148
# Epoch: 76, Discriminator Loss:  0.2421, Generator Loss:  0.0321
# Epoch: 77, Discriminator Loss:  0.2407, Generator Loss:  0.0196
# Epoch: 78, Discriminator Loss:  0.2336, Generator Loss:  0.0190
# Epoch: 79, Discriminator Loss:  0.2433, Generator Loss:  0.0383
# Epoch: 80, Discriminator Loss:  0.2590, Generator Loss:  0.0313
# Epoch: 81, Discriminator Loss:  0.2343, Generator Loss:  0.0438
# Epoch: 82, Discriminator Loss:  0.1937, Generator Loss:  0.0502
# Epoch: 83, Discriminator Loss:  0.2531, Generator Loss:  0.0063
# Epoch: 84, Discriminator Loss:  0.2781, Generator Loss:  0.0188
# Epoch: 85, Discriminator Loss:  0.2312, Generator Loss:  0.0125
# Epoch: 86, Discriminator Loss:  0.2062, Generator Loss:  0.0188
# Epoch: 87, Discriminator Loss:  0.2281, Generator Loss:  0.0250
# Epoch: 88, Discriminator Loss:  0.2875, Generator Loss:  0.0250
# Epoch: 89, Discriminator Loss:  0.2000, Generator Loss:  0.0312
# Epoch: 90, Discriminator Loss:  0.2219, Generator Loss:  0.0188
# Epoch: 91, Discriminator Loss:  0.2500, Generator Loss:  0.0250
# Epoch: 92, Discriminator Loss:  0.2531, Generator Loss:  0.0500
# Epoch: 93, Discriminator Loss:  0.2406, Generator Loss:  0.0125
# Epoch: 94, Discriminator Loss:  0.2781, Generator Loss:  0.0250
# Epoch: 95, Discriminator Loss:  0.2562, Generator Loss:  0.0063
# Epoch: 96, Discriminator Loss:  0.2094, Generator Loss:  0.0000
# Epoch: 97, Discriminator Loss:  0.2156, Generator Loss:  0.0250
# Epoch: 98, Discriminator Loss:  0.2406, Generator Loss:  0.0437
# Epoch: 99, Discriminator Loss:  0.2437, Generator Loss:  0.0250
# Epoch: 100, Discriminator Loss:  0.2094, Generator Loss:  0.0312
# Epoch: 101, Discriminator Loss:  0.2562, Generator Loss:  0.0188
# Epoch: 102, Discriminator Loss:  0.2438, Generator Loss:  0.0250
# Epoch: 103, Discriminator Loss:  0.2313, Generator Loss:  0.0312
# Epoch: 104, Discriminator Loss:  0.2281, Generator Loss:  0.0312
# Epoch: 105, Discriminator Loss:  0.2156, Generator Loss:  0.0312
# Epoch: 106, Discriminator Loss:  0.2562, Generator Loss:  0.0188
# Epoch: 107, Discriminator Loss:  0.2500, Generator Loss:  0.0125
# Epoch: 108, Discriminator Loss:  0.2688, Generator Loss:  0.0188
# Epoch: 109, Discriminator Loss:  0.2250, Generator Loss:  0.0437
# Epoch: 110, Discriminator Loss:  0.2562, Generator Loss:  0.0188
# Epoch: 111, Discriminator Loss:  0.2188, Generator Loss:  0.0188
# Epoch: 112, Discriminator Loss:  0.2344, Generator Loss:  0.0188
# Epoch: 113, Discriminator Loss:  0.2062, Generator Loss:  0.0188
# Epoch: 114, Discriminator Loss:  0.2406, Generator Loss:  0.0125
# Epoch: 115, Discriminator Loss:  0.2406, Generator Loss:  0.0125
# Epoch: 116, Discriminator Loss:  0.2469, Generator Loss:  0.0188
# Epoch: 117, Discriminator Loss:  0.2500, Generator Loss:  0.0125
# Epoch: 118, Discriminator Loss:  0.2063, Generator Loss:  0.0375
# Epoch: 119, Discriminator Loss:  0.2469, Generator Loss:  0.0437
# Epoch: 120, Discriminator Loss:  0.2750, Generator Loss:  0.0437
# Epoch: 121, Discriminator Loss:  0.2375, Generator Loss:  0.0312
# Epoch: 122, Discriminator Loss:  0.2000, Generator Loss:  0.0375
# Epoch: 123, Discriminator Loss:  0.2156, Generator Loss:  0.0375
# Epoch: 124, Discriminator Loss:  0.2188, Generator Loss:  0.0312
# Epoch: 125, Discriminator Loss:  0.2156, Generator Loss:  0.0188
# Epoch: 126, Discriminator Loss:  0.1906, Generator Loss:  0.0312
# Epoch: 127, Discriminator Loss:  0.2188, Generator Loss:  0.0188
# Epoch: 128, Discriminator Loss:  0.2375, Generator Loss:  0.0188
# Epoch: 129, Discriminator Loss:  0.2062, Generator Loss:  0.0312
# Epoch: 130, Discriminator Loss:  0.2438, Generator Loss:  0.0250
# Epoch: 131, Discriminator Loss:  0.2281, Generator Loss:  0.0437
# Epoch: 132, Discriminator Loss:  0.2719, Generator Loss:  0.0250
# Epoch: 133, Discriminator Loss:  0.2250, Generator Loss:  0.0125
# Epoch: 134, Discriminator Loss:  0.2406, Generator Loss:  0.0437
# Epoch: 135, Discriminator Loss:  0.2656, Generator Loss:  0.0063
# Epoch: 136, Discriminator Loss:  0.2375, Generator Loss:  0.0125
# Epoch: 137, Discriminator Loss:  0.2344, Generator Loss:  0.0250
# Epoch: 138, Discriminator Loss:  0.2469, Generator Loss:  0.0250
# Epoch: 139, Discriminator Loss:  0.2062, Generator Loss:  0.0375
# Epoch: 140, Discriminator Loss:  0.2000, Generator Loss:  0.0375
# Epoch: 141, Discriminator Loss:  0.2531, Generator Loss:  0.0063
# Epoch: 142, Discriminator Loss:  0.2312, Generator Loss:  0.0188
# Epoch: 143, Discriminator Loss:  0.2312, Generator Loss:  0.0437
# Epoch: 144, Discriminator Loss:  0.2438, Generator Loss:  0.0125
# Epoch: 145, Discriminator Loss:  0.2500, Generator Loss:  0.0312
# Epoch: 146, Discriminator Loss:  0.2531, Generator Loss:  0.0312
# Epoch: 147, Discriminator Loss:  0.1906, Generator Loss:  0.0188
# Epoch: 148, Discriminator Loss:  0.2469, Generator Loss:  0.0250
# Epoch: 149, Discriminator Loss:  0.2250, Generator Loss:  0.0063
# Epoch: 150, Discriminator Loss:  0.2062, Generator Loss:  0.0375
# Epoch: 151, Discriminator Loss:  0.2594, Generator Loss:  0.0188
# Epoch: 152, Discriminator Loss:  0.2625, Generator Loss:  0.0188
# Epoch: 153, Discriminator Loss:  0.2187, Generator Loss:  0.0375
# Epoch: 154, Discriminator Loss:  0.2406, Generator Loss:  0.0250
# Epoch: 155, Discriminator Loss:  0.2281, Generator Loss:  0.0312
# Epoch: 156, Discriminator Loss:  0.2344, Generator Loss:  0.0375
# Epoch: 157, Discriminator Loss:  0.2313, Generator Loss:  0.0250
# Epoch: 158, Discriminator Loss:  0.2313, Generator Loss:  0.0437
# Epoch: 159, Discriminator Loss:  0.2531, Generator Loss:  0.0188
# Epoch: 160, Discriminator Loss:  0.2656, Generator Loss:  0.0063
# Epoch: 161, Discriminator Loss:  0.2187, Generator Loss:  0.0437
# Epoch: 162, Discriminator Loss:  0.2500, Generator Loss:  0.0188
# Epoch: 163, Discriminator Loss:  0.2281, Generator Loss:  0.0375
# Epoch: 164, Discriminator Loss:  0.2594, Generator Loss:  0.0312
# Epoch: 165, Discriminator Loss:  0.2313, Generator Loss:  0.0125
# Epoch: 166, Discriminator Loss:  0.2313, Generator Loss:  0.0562
# Epoch: 167, Discriminator Loss:  0.2281, Generator Loss:  0.0375
# Epoch: 168, Discriminator Loss:  0.2500, Generator Loss:  0.0188
# Epoch: 169, Discriminator Loss:  0.2156, Generator Loss:  0.0312
# Epoch: 170, Discriminator Loss:  0.2125, Generator Loss:  0.0375
# Epoch: 171, Discriminator Loss:  0.2406, Generator Loss:  0.0250
# Epoch: 172, Discriminator Loss:  0.2625, Generator Loss:  0.0188
# Epoch: 173, Discriminator Loss:  0.2562, Generator Loss:  0.0125
# Epoch: 174, Discriminator Loss:  0.2500, Generator Loss:  0.0375
# Epoch: 175, Discriminator Loss:  0.2375, Generator Loss:  0.0312
# Epoch: 176, Discriminator Loss:  0.2062, Generator Loss:  0.0437
# Epoch: 177, Discriminator Loss:  0.2281, Generator Loss:  0.0000
# Epoch: 178, Discriminator Loss:  0.2188, Generator Loss:  0.0188
# Epoch: 179, Discriminator Loss:  0.2250, Generator Loss:  0.0125
# Epoch: 180, Discriminator Loss:  0.2375, Generator Loss:  0.0375
# Epoch: 181, Discriminator Loss:  0.2438, Generator Loss:  0.0250
# Epoch: 182, Discriminator Loss:  0.2281, Generator Loss:  0.0312
# Epoch: 183, Discriminator Loss:  0.2500, Generator Loss:  0.0375
# Epoch: 184, Discriminator Loss:  0.2469, Generator Loss:  0.0312
# Epoch: 185, Discriminator Loss:  0.1938, Generator Loss:  0.0125
# Epoch: 186, Discriminator Loss:  0.2281, Generator Loss:  0.0250
# Epoch: 187, Discriminator Loss:  0.2250, Generator Loss:  0.0188
# Epoch: 188, Discriminator Loss:  0.2344, Generator Loss:  0.0063
# Epoch: 189, Discriminator Loss:  0.2188, Generator Loss:  0.0250
# Epoch: 190, Discriminator Loss:  0.2781, Generator Loss:  0.0437
# Epoch: 191, Discriminator Loss:  0.2219, Generator Loss:  0.0312
# Epoch: 192, Discriminator Loss:  0.2281, Generator Loss:  0.0437
# Epoch: 193, Discriminator Loss:  0.2563, Generator Loss:  0.0312
# Epoch: 194, Discriminator Loss:  0.2656, Generator Loss:  0.0250
# Epoch: 195, Discriminator Loss:  0.2312, Generator Loss:  0.0375
# Epoch: 196, Discriminator Loss:  0.2156, Generator Loss:  0.0250
# Epoch: 197, Discriminator Loss:  0.2688, Generator Loss:  0.0375
# Epoch: 198, Discriminator Loss:  0.2500, Generator Loss:  0.0250
# Epoch: 199, Discriminator Loss:  0.2250, Generator Loss:  0.0125
# Epoch: 200, Discriminator Loss:  0.2406, Generator Loss:  0.0250
# Epoch: 201, Discriminator Loss:  0.2125, Generator Loss:  0.0188
# Epoch: 202, Discriminator Loss:  0.2156, Generator Loss:  0.0125
# Epoch: 203, Discriminator Loss:  0.2219, Generator Loss:  0.0375
# Epoch: 204, Discriminator Loss:  0.2375, Generator Loss:  0.0250
# Epoch: 205, Discriminator Loss:  0.2375, Generator Loss:  0.0188
# Epoch: 206, Discriminator Loss:  0.2344, Generator Loss:  0.0312
# Epoch: 207, Discriminator Loss:  0.2125, Generator Loss:  0.0250
# Epoch: 208, Discriminator Loss:  0.2500, Generator Loss:  0.0500
# Epoch: 209, Discriminator Loss:  0.2375, Generator Loss:  0.0188
# Epoch: 210, Discriminator Loss:  0.2125, Generator Loss:  0.0188
# Epoch: 211, Discriminator Loss:  0.2531, Generator Loss:  0.0063
# Epoch: 212, Discriminator Loss:  0.2438, Generator Loss:  0.0188
# Epoch: 213, Discriminator Loss:  0.2594, Generator Loss:  0.0312
# Epoch: 214, Discriminator Loss:  0.2406, Generator Loss:  0.0375
# Epoch: 215, Discriminator Loss:  0.2625, Generator Loss:  0.0188
# Epoch: 216, Discriminator Loss:  0.2375, Generator Loss:  0.0375
# Epoch: 217, Discriminator Loss:  0.2438, Generator Loss:  0.0188
# Epoch: 218, Discriminator Loss:  0.2156, Generator Loss:  0.0250
# Epoch: 219, Discriminator Loss:  0.2562, Generator Loss:  0.0312
# Epoch: 220, Discriminator Loss:  0.2531, Generator Loss:  0.0125
# Epoch: 221, Discriminator Loss:  0.2656, Generator Loss:  0.0188
# Epoch: 222, Discriminator Loss:  0.2375, Generator Loss:  0.0125
# Epoch: 223, Discriminator Loss:  0.2594, Generator Loss:  0.0437
# Epoch: 224, Discriminator Loss:  0.2719, Generator Loss:  0.0250
# Epoch: 225, Discriminator Loss:  0.2406, Generator Loss:  0.0312
# Epoch: 226, Discriminator Loss:  0.2438, Generator Loss:  0.0500
# Epoch: 227, Discriminator Loss:  0.2531, Generator Loss:  0.0188
# Epoch: 228, Discriminator Loss:  0.2125, Generator Loss:  0.0437
# Epoch: 229, Discriminator Loss:  0.2000, Generator Loss:  0.0562
# Epoch: 230, Discriminator Loss:  0.1875, Generator Loss:  0.0188
# Epoch: 231, Discriminator Loss:  0.2094, Generator Loss:  0.0063
# Epoch: 232, Discriminator Loss:  0.2656, Generator Loss:  0.0250
# Epoch: 233, Discriminator Loss:  0.2781, Generator Loss:  0.0125
# Epoch: 234, Discriminator Loss:  0.2438, Generator Loss:  0.0188
# Epoch: 235, Discriminator Loss:  0.2000, Generator Loss:  0.0500
# Epoch: 236, Discriminator Loss:  0.2375, Generator Loss:  0.0250
# Epoch: 237, Discriminator Loss:  0.2469, Generator Loss:  0.0188
# Epoch: 238, Discriminator Loss:  0.2812, Generator Loss:  0.0125
# Epoch: 239, Discriminator Loss:  0.2438, Generator Loss:  0.0437
# Epoch: 240, Discriminator Loss:  0.2344, Generator Loss:  0.0250
# Epoch: 241, Discriminator Loss:  0.2594, Generator Loss:  0.0250
# Epoch: 242, Discriminator Loss:  0.2375, Generator Loss:  0.0312
# Epoch: 243, Discriminator Loss:  0.2500, Generator Loss:  0.0250
# Epoch: 244, Discriminator Loss:  0.2469, Generator Loss:  0.0250
# Epoch: 245, Discriminator Loss:  0.2531, Generator Loss:  0.0125
# Epoch: 246, Discriminator Loss:  0.2250, Generator Loss:  0.0250
# Epoch: 247, Discriminator Loss:  0.2719, Generator Loss:  0.0437
# Epoch: 248, Discriminator Loss:  0.2375, Generator Loss:  0.0063
# Epoch: 249, Discriminator Loss:  0.2406, Generator Loss:  0.0250
# Epoch: 250, Discriminator Loss:  0.2438, Generator Loss:  0.0312
# Epoch: 251, Discriminator Loss:  0.2281, Generator Loss:  0.0250
# Epoch: 252, Discriminator Loss:  0.2625, Generator Loss:  0.0250
# Epoch: 253, Discriminator Loss:  0.2562, Generator Loss:  0.0312
# Epoch: 254, Discriminator Loss:  0.2375, Generator Loss:  0.0437
# Epoch: 255, Discriminator Loss:  0.2594, Generator Loss:  0.0375
# Epoch: 256, Discriminator Loss:  0.2812, Generator Loss:  0.0188
# Epoch: 257, Discriminator Loss:  0.2438, Generator Loss:  0.0125
# Epoch: 258, Discriminator Loss:  0.2500, Generator Loss:  0.0375
# Epoch: 259, Discriminator Loss:  0.2344, Generator Loss:  0.0250
# Epoch: 260, Discriminator Loss:  0.2469, Generator Loss:  0.0250
# Epoch: 261, Discriminator Loss:  0.2656, Generator Loss:  0.0437
# Epoch: 262, Discriminator Loss:  0.2625, Generator Loss:  0.0125
# Epoch: 263, Discriminator Loss:  0.2312, Generator Loss:  0.0312
# Epoch: 264, Discriminator Loss:  0.2344, Generator Loss:  0.0250
# Epoch: 265, Discriminator Loss:  0.2625, Generator Loss:  0.0250
# Epoch: 266, Discriminator Loss:  0.2031, Generator Loss:  0.0125
# Epoch: 267, Discriminator Loss:  0.3031, Generator Loss:  0.0188
# Epoch: 268, Discriminator Loss:  0.2156, Generator Loss:  0.0125
# Epoch: 269, Discriminator Loss:  0.2313, Generator Loss:  0.0375
# Epoch: 270, Discriminator Loss:  0.2156, Generator Loss:  0.0250
# Epoch: 271, Discriminator Loss:  0.2344, Generator Loss:  0.0250
# Epoch: 272, Discriminator Loss:  0.2438, Generator Loss:  0.0562
# Epoch: 273, Discriminator Loss:  0.2344, Generator Loss:  0.0250
# Epoch: 274, Discriminator Loss:  0.2500, Generator Loss:  0.0375
# Epoch: 275, Discriminator Loss:  0.2406, Generator Loss:  0.0375
# Epoch: 276, Discriminator Loss:  0.2313, Generator Loss:  0.0250
# Epoch: 277, Discriminator Loss:  0.2188, Generator Loss:  0.0063
# Epoch: 278, Discriminator Loss:  0.2281, Generator Loss:  0.0063
# Epoch: 279, Discriminator Loss:  0.2500, Generator Loss:  0.0188
# Epoch: 280, Discriminator Loss:  0.2188, Generator Loss:  0.0188
# Epoch: 281, Discriminator Loss:  0.2281, Generator Loss:  0.0188
# Epoch: 282, Discriminator Loss:  0.2438, Generator Loss:  0.0125
# Epoch: 283, Discriminator Loss:  0.2313, Generator Loss:  0.0437
# Epoch: 284, Discriminator Loss:  0.2188, Generator Loss:  0.0188
# Epoch: 285, Discriminator Loss:  0.2219, Generator Loss:  0.0250
# Epoch: 286, Discriminator Loss:  0.2281, Generator Loss:  0.0188
# Epoch: 287, Discriminator Loss:  0.2406, Generator Loss:  0.0312
# Epoch: 288, Discriminator Loss:  0.2406, Generator Loss:  0.0250
# Epoch: 289, Discriminator Loss:  0.2500, Generator Loss:  0.0312
# Epoch: 290, Discriminator Loss:  0.2281, Generator Loss:  0.0250
# Epoch: 291, Discriminator Loss:  0.2000, Generator Loss:  0.0312
# Epoch: 292, Discriminator Loss:  0.2188, Generator Loss:  0.0250
# Epoch: 293, Discriminator Loss:  0.2688, Generator Loss:  0.0250
# Epoch: 294, Discriminator Loss:  0.2687, Generator Loss:  0.0125
# Epoch: 295, Discriminator Loss:  0.2531, Generator Loss:  0.0125
# Epoch: 296, Discriminator Loss:  0.2188, Generator Loss:  0.0437
# Epoch: 297, Discriminator Loss:  0.2375, Generator Loss:  0.0188
# Epoch: 298, Discriminator Loss:  0.2406, Generator Loss:  0.0125
# Epoch: 299, Discriminator Loss:  0.2531, Generator Loss:  0.0188
# Epoch: 300, Discriminator Loss:  0.2562, Generator Loss:  0.0375
# Epoch: 301, Discriminator Loss:  0.2531, Generator Loss:  0.0250
# Epoch: 302, Discriminator Loss:  0.2406, Generator Loss:  0.0312
# Epoch: 303, Discriminator Loss:  0.2375, Generator Loss:  0.0375
# Epoch: 304, Discriminator Loss:  0.2562, Generator Loss:  0.0312
# Epoch: 305, Discriminator Loss:  0.1969, Generator Loss:  0.0188
# Epoch: 306, Discriminator Loss:  0.2500, Generator Loss:  0.0312
# Epoch: 307, Discriminator Loss:  0.2250, Generator Loss:  0.0437
# Epoch: 308, Discriminator Loss:  0.2250, Generator Loss:  0.0312
# Epoch: 309, Discriminator Loss:  0.2313, Generator Loss:  0.0125
# Epoch: 310, Discriminator Loss:  0.2313, Generator Loss:  0.0250
# Epoch: 311, Discriminator Loss:  0.2469, Generator Loss:  0.0250
# Epoch: 312, Discriminator Loss:  0.2594, Generator Loss:  0.0312
# Epoch: 313, Discriminator Loss:  0.2406, Generator Loss:  0.0125
# Epoch: 314, Discriminator Loss:  0.2281, Generator Loss:  0.0125
# Epoch: 315, Discriminator Loss:  0.2406, Generator Loss:  0.0125
# Epoch: 316, Discriminator Loss:  0.2656, Generator Loss:  0.0312
# Epoch: 317, Discriminator Loss:  0.2375, Generator Loss:  0.0063
# Epoch: 318, Discriminator Loss:  0.2188, Generator Loss:  0.0250
# Epoch: 319, Discriminator Loss:  0.2469, Generator Loss:  0.0312
# Epoch: 320, Discriminator Loss:  0.2375, Generator Loss:  0.0188
# Epoch: 321, Discriminator Loss:  0.2531, Generator Loss:  0.0188
# Epoch: 322, Discriminator Loss:  0.2500, Generator Loss:  0.0375
# Epoch: 323, Discriminator Loss:  0.2031, Generator Loss:  0.0250
# Epoch: 324, Discriminator Loss:  0.2313, Generator Loss:  0.0125
# Epoch: 325, Discriminator Loss:  0.2250, Generator Loss:  0.0188
# Epoch: 326, Discriminator Loss:  0.2719, Generator Loss:  0.0188
# Epoch: 327, Discriminator Loss:  0.1969, Generator Loss:  0.0188
# Epoch: 328, Discriminator Loss:  0.2562, Generator Loss:  0.0063
# Epoch: 329, Discriminator Loss:  0.2688, Generator Loss:  0.0375
# Epoch: 330, Discriminator Loss:  0.2469, Generator Loss:  0.0188
# Epoch: 331, Discriminator Loss:  0.2250, Generator Loss:  0.0063
# Epoch: 332, Discriminator Loss:  0.2219, Generator Loss:  0.0375
# Epoch: 333, Discriminator Loss:  0.2344, Generator Loss:  0.0250
# Epoch: 334, Discriminator Loss:  0.2375, Generator Loss:  0.0250
# Epoch: 335, Discriminator Loss:  0.2313, Generator Loss:  0.0125
# Epoch: 336, Discriminator Loss:  0.2188, Generator Loss:  0.0312
# Epoch: 337, Discriminator Loss:  0.2406, Generator Loss:  0.0375
# Epoch: 338, Discriminator Loss:  0.2562, Generator Loss:  0.0250
# Epoch: 339, Discriminator Loss:  0.2125, Generator Loss:  0.0312
# Epoch: 340, Discriminator Loss:  0.2250, Generator Loss:  0.0500
# Epoch: 341, Discriminator Loss:  0.2406, Generator Loss:  0.0063
# Epoch: 342, Discriminator Loss:  0.2531, Generator Loss:  0.0250
# Epoch: 343, Discriminator Loss:  0.2406, Generator Loss:  0.0250
# Epoch: 344, Discriminator Loss:  0.2594, Generator Loss:  0.0312
# Epoch: 345, Discriminator Loss:  0.2500, Generator Loss:  0.0500
# Epoch: 346, Discriminator Loss:  0.2281, Generator Loss:  0.0312
# Epoch: 347, Discriminator Loss:  0.2719, Generator Loss:  0.0125
# Epoch: 348, Discriminator Loss:  0.2375, Generator Loss:  0.0188
# Epoch: 349, Discriminator Loss:  0.2688, Generator Loss:  0.0188
# Epoch: 350, Discriminator Loss:  0.2375, Generator Loss:  0.0125
# Epoch: 351, Discriminator Loss:  0.2187, Generator Loss:  0.0125
# Epoch: 352, Discriminator Loss:  0.2406, Generator Loss:  0.0188
# Epoch: 353, Discriminator Loss:  0.2906, Generator Loss:  0.0312
# Epoch: 354, Discriminator Loss:  0.2406, Generator Loss:  0.0375
# Epoch: 355, Discriminator Loss:  0.2469, Generator Loss:  0.0000
# Epoch: 356, Discriminator Loss:  0.2313, Generator Loss:  0.0063
# Epoch: 357, Discriminator Loss:  0.2250, Generator Loss:  0.0312
# Epoch: 358, Discriminator Loss:  0.2531, Generator Loss:  0.0312
# Epoch: 359, Discriminator Loss:  0.2000, Generator Loss:  0.0500
# Epoch: 360, Discriminator Loss:  0.2344, Generator Loss:  0.0188
# Epoch: 361, Discriminator Loss:  0.2375, Generator Loss:  0.0312
# Epoch: 362, Discriminator Loss:  0.1937, Generator Loss:  0.0125
# Epoch: 363, Discriminator Loss:  0.2531, Generator Loss:  0.0312
# Epoch: 364, Discriminator Loss:  0.2375, Generator Loss:  0.0188
# Epoch: 365, Discriminator Loss:  0.2156, Generator Loss:  0.0375
# Epoch: 366, Discriminator Loss:  0.2031, Generator Loss:  0.0250
# Epoch: 367, Discriminator Loss:  0.2219, Generator Loss:  0.0312
# Epoch: 368, Discriminator Loss:  0.2844, Generator Loss:  0.0312
# Epoch: 369, Discriminator Loss:  0.2375, Generator Loss:  0.0250
# Epoch: 370, Discriminator Loss:  0.2313, Generator Loss:  0.0250
# Epoch: 371, Discriminator Loss:  0.2344, Generator Loss:  0.0188
# Epoch: 372, Discriminator Loss:  0.2156, Generator Loss:  0.0312
# Epoch: 373, Discriminator Loss:  0.2281, Generator Loss:  0.0375
# Epoch: 374, Discriminator Loss:  0.2344, Generator Loss:  0.0250
# Epoch: 375, Discriminator Loss:  0.2344, Generator Loss:  0.0188
# Epoch: 376, Discriminator Loss:  0.2062, Generator Loss:  0.0312
# Epoch: 377, Discriminator Loss:  0.2281, Generator Loss:  0.0312
# Epoch: 378, Discriminator Loss:  0.2500, Generator Loss:  0.0312
# Epoch: 379, Discriminator Loss:  0.2406, Generator Loss:  0.0375
# Epoch: 380, Discriminator Loss:  0.2219, Generator Loss:  0.0188
# Epoch: 381, Discriminator Loss:  0.2344, Generator Loss:  0.0188
# Epoch: 382, Discriminator Loss:  0.2469, Generator Loss:  0.0250
# Epoch: 383, Discriminator Loss:  0.2469, Generator Loss:  0.0437
# Epoch: 384, Discriminator Loss:  0.2594, Generator Loss:  0.0188
# Epoch: 385, Discriminator Loss:  0.2406, Generator Loss:  0.0250
# Epoch: 386, Discriminator Loss:  0.2562, Generator Loss:  0.0125
# Epoch: 387, Discriminator Loss:  0.2625, Generator Loss:  0.0250
# Epoch: 388, Discriminator Loss:  0.2406, Generator Loss:  0.0125
# Epoch: 389, Discriminator Loss:  0.2594, Generator Loss:  0.0250
# Epoch: 390, Discriminator Loss:  0.2031, Generator Loss:  0.0437
# Epoch: 391, Discriminator Loss:  0.2031, Generator Loss:  0.0188
# Epoch: 392, Discriminator Loss:  0.2219, Generator Loss:  0.0188
# Epoch: 393, Discriminator Loss:  0.2219, Generator Loss:  0.0125
# Epoch: 394, Discriminator Loss:  0.2844, Generator Loss:  0.0250
# Epoch: 395, Discriminator Loss:  0.2438, Generator Loss:  0.0250
# Epoch: 396, Discriminator Loss:  0.2344, Generator Loss:  0.0188
# Epoch: 397, Discriminator Loss:  0.2562, Generator Loss:  0.0125
# Epoch: 398, Discriminator Loss:  0.2469, Generator Loss:  0.0188
# Epoch: 399, Discriminator Loss:  0.2375, Generator Loss:  0.0312
# Epoch: 400, Discriminator Loss:  0.2094, Generator Loss:  0.0188
# Epoch: 401, Discriminator Loss:  0.2062, Generator Loss:  0.0250
# Epoch: 402, Discriminator Loss:  0.2094, Generator Loss:  0.0250
# Epoch: 403, Discriminator Loss:  0.2375, Generator Loss:  0.0188
# Epoch: 404, Discriminator Loss:  0.2656, Generator Loss:  0.0188
# Epoch: 405, Discriminator Loss:  0.2188, Generator Loss:  0.0188
# Epoch: 406, Discriminator Loss:  0.2625, Generator Loss:  0.0312
# Epoch: 407, Discriminator Loss:  0.2062, Generator Loss:  0.0250
# Epoch: 408, Discriminator Loss:  0.2375, Generator Loss:  0.0312
# Epoch: 409, Discriminator Loss:  0.2219, Generator Loss:  0.0188
# Epoch: 410, Discriminator Loss:  0.2219, Generator Loss:  0.0250
# Epoch: 411, Discriminator Loss:  0.2250, Generator Loss:  0.0250
# Epoch: 412, Discriminator Loss:  0.2312, Generator Loss:  0.0188
# Epoch: 413, Discriminator Loss:  0.2531, Generator Loss:  0.0125
# Epoch: 414, Discriminator Loss:  0.2500, Generator Loss:  0.0188
# Epoch: 415, Discriminator Loss:  0.2375, Generator Loss:  0.0375
# Epoch: 416, Discriminator Loss:  0.2344, Generator Loss:  0.0188
# Epoch: 417, Discriminator Loss:  0.2219, Generator Loss:  0.0125
# Epoch: 418, Discriminator Loss:  0.2281, Generator Loss:  0.0312
# Epoch: 419, Discriminator Loss:  0.1844, Generator Loss:  0.0250
# Epoch: 420, Discriminator Loss:  0.2062, Generator Loss:  0.0250
# Epoch: 421, Discriminator Loss:  0.2344, Generator Loss:  0.0437
# Epoch: 422, Discriminator Loss:  0.2594, Generator Loss:  0.0125
# Epoch: 423, Discriminator Loss:  0.2438, Generator Loss:  0.0250
# Epoch: 424, Discriminator Loss:  0.2469, Generator Loss:  0.0188
# Epoch: 425, Discriminator Loss:  0.2344, Generator Loss:  0.0375
# Epoch: 426, Discriminator Loss:  0.2125, Generator Loss:  0.0188
# Epoch: 427, Discriminator Loss:  0.2313, Generator Loss:  0.0312
# Epoch: 428, Discriminator Loss:  0.2438, Generator Loss:  0.0375
# Epoch: 429, Discriminator Loss:  0.2656, Generator Loss:  0.0188
# Epoch: 430, Discriminator Loss:  0.2063, Generator Loss:  0.0250
# Epoch: 431, Discriminator Loss:  0.2219, Generator Loss:  0.0375
# Epoch: 432, Discriminator Loss:  0.2531, Generator Loss:  0.0312
# Epoch: 433, Discriminator Loss:  0.1969, Generator Loss:  0.0250
# Epoch: 434, Discriminator Loss:  0.2344, Generator Loss:  0.0188
# Epoch: 435, Discriminator Loss:  0.2406, Generator Loss:  0.0375
# Epoch: 436, Discriminator Loss:  0.2250, Generator Loss:  0.0250
# Epoch: 437, Discriminator Loss:  0.2125, Generator Loss:  0.0250
# Epoch: 438, Discriminator Loss:  0.2719, Generator Loss:  0.0375
# Epoch: 439, Discriminator Loss:  0.2281, Generator Loss:  0.0562
# Epoch: 440, Discriminator Loss:  0.2406, Generator Loss:  0.0312
# Epoch: 441, Discriminator Loss:  0.2500, Generator Loss:  0.0312
# Epoch: 442, Discriminator Loss:  0.2438, Generator Loss:  0.0312
# Epoch: 443, Discriminator Loss:  0.2469, Generator Loss:  0.0437
# Epoch: 444, Discriminator Loss:  0.2219, Generator Loss:  0.0000
# Epoch: 445, Discriminator Loss:  0.2125, Generator Loss:  0.0125
# Epoch: 446, Discriminator Loss:  0.2437, Generator Loss:  0.0188
# Epoch: 447, Discriminator Loss:  0.2469, Generator Loss:  0.0375
# Epoch: 448, Discriminator Loss:  0.2375, Generator Loss:  0.0125
# Epoch: 449, Discriminator Loss:  0.2375, Generator Loss:  0.0125
# Epoch: 450, Discriminator Loss:  0.2156, Generator Loss:  0.0312
# Epoch: 451, Discriminator Loss:  0.2406, Generator Loss:  0.0188
# Epoch: 452, Discriminator Loss:  0.2469, Generator Loss:  0.0250
# Epoch: 453, Discriminator Loss:  0.2406, Generator Loss:  0.0250
# Epoch: 454, Discriminator Loss:  0.2500, Generator Loss:  0.0250
# Epoch: 455, Discriminator Loss:  0.2563, Generator Loss:  0.0125
# Epoch: 456, Discriminator Loss:  0.2313, Generator Loss:  0.0125
# Epoch: 457, Discriminator Loss:  0.2375, Generator Loss:  0.0063
# Epoch: 458, Discriminator Loss:  0.2500, Generator Loss:  0.0250
# Epoch: 459, Discriminator Loss:  0.2344, Generator Loss:  0.0312
# Epoch: 460, Discriminator Loss:  0.2375, Generator Loss:  0.0125
# Epoch: 461, Discriminator Loss:  0.2812, Generator Loss:  0.0312
# Epoch: 462, Discriminator Loss:  0.2156, Generator Loss:  0.0250
# Epoch: 463, Discriminator Loss:  0.2250, Generator Loss:  0.0250
# Epoch: 464, Discriminator Loss:  0.2281, Generator Loss:  0.0188
# Epoch: 465, Discriminator Loss:  0.2125, Generator Loss:  0.0312
# Epoch: 466, Discriminator Loss:  0.2313, Generator Loss:  0.0250
# Epoch: 467, Discriminator Loss:  0.2406, Generator Loss:  0.0125
# Epoch: 468, Discriminator Loss:  0.2031, Generator Loss:  0.0312
# Epoch: 469, Discriminator Loss:  0.2469, Generator Loss:  0.0188
# Epoch: 470, Discriminator Loss:  0.2406, Generator Loss:  0.0312
# Epoch: 471, Discriminator Loss:  0.2562, Generator Loss:  0.0250
# Epoch: 472, Discriminator Loss:  0.2375, Generator Loss:  0.0312
# Epoch: 473, Discriminator Loss:  0.2188, Generator Loss:  0.0250
# Epoch: 474, Discriminator Loss:  0.2375, Generator Loss:  0.0500
# Epoch: 475, Discriminator Loss:  0.2438, Generator Loss:  0.0188
# Epoch: 476, Discriminator Loss:  0.2375, Generator Loss:  0.0250
# Epoch: 477, Discriminator Loss:  0.1906, Generator Loss:  0.0250
# Epoch: 478, Discriminator Loss:  0.1969, Generator Loss:  0.0188
# Epoch: 479, Discriminator Loss:  0.2344, Generator Loss:  0.0250
# Epoch: 480, Discriminator Loss:  0.2375, Generator Loss:  0.0250
# Epoch: 481, Discriminator Loss:  0.2156, Generator Loss:  0.0250
# Epoch: 482, Discriminator Loss:  0.2313, Generator Loss:  0.0188
# Epoch: 483, Discriminator Loss:  0.2625, Generator Loss:  0.0125
# Epoch: 484, Discriminator Loss:  0.2406, Generator Loss:  0.0188
# Epoch: 485, Discriminator Loss:  0.2531, Generator Loss:  0.0312
# Epoch: 486, Discriminator Loss:  0.2344, Generator Loss:  0.0250
# Epoch: 487, Discriminator Loss:  0.2375, Generator Loss:  0.0312
# Epoch: 488, Discriminator Loss:  0.2500, Generator Loss:  0.0437
# Epoch: 489, Discriminator Loss:  0.2438, Generator Loss:  0.0063
# Epoch: 490, Discriminator Loss:  0.2531, Generator Loss:  0.0250
# Epoch: 491, Discriminator Loss:  0.2313, Generator Loss:  0.0312
# Epoch: 492, Discriminator Loss:  0.2156, Generator Loss:  0.0312
# Epoch: 493, Discriminator Loss:  0.2781, Generator Loss:  0.0312
# Epoch: 494, Discriminator Loss:  0.2656, Generator Loss:  0.0188
# Epoch: 495, Discriminator Loss:  0.2469, Generator Loss:  0.0188
# Epoch: 496, Discriminator Loss:  0.2313, Generator Loss:  0.0250
# Epoch: 497, Discriminator Loss:  0.2188, Generator Loss:  0.0312
# Epoch: 498, Discriminator Loss:  0.2219, Generator Loss:  0.0188
# Epoch: 499, Discriminator Loss:  0.2281, Generator Loss:  0.0063
# Epoch: 500, Discriminator Loss:  0.2156, Generator Loss:  0.0188
